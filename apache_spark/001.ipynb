# %%
# %sql

DROP TABLE IF EXISTS diamonds;

CREATE TABLE diamonds USING CSV OPTIONS (path "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv", header "true")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
spark.sql("SELECT * FROM diamonds").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# _c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
#   1| 0.23|    Ideal|    E|    SI2| 61.5|   55|  326|3.95|3.98|2.43|
#   2| 0.21|  Premium|    E|    SI1| 59.8|   61|  326|3.89|3.84|2.31|
#   3| 0.23|     Good|    E|    VS1| 56.9|   65|  327|4.05|4.07|2.31|
#   4| 0.29|  Premium|    I|    VS2| 62.4|   58|  334| 4.2|4.23|2.63|
#   5| 0.31|     Good|    J|    SI2| 63.3|   58|  335|4.34|4.35|2.75|
#   6| 0.24|Very Good|    J|   VVS2| 62.8|   57|  336|3.94|3.96|2.48|
#   7| 0.24|Very Good|    I|   VVS1| 62.3|   57|  336|3.95|3.98|2.47|
#   8| 0.26|Very Good|    H|    SI1| 61.9|   55|  337|4.07|4.11|2.53|
#   9| 0.22|     Fair|    E|    VS2| 65.1|   61|  337|3.87|3.78|2.49|
#  10| 0.23|Very Good|    H|    VS1| 59.4|   61|  338|   4|4.05|2.39|
#  11|  0.3|     Good|    J|    SI1|   64|   55|  339|4.25|4.28|2.73|
#  12| 0.23|    Ideal|    J|    VS1| 62.8|   56|  340|3.93| 3.9|2.46|
#  13| 0.22|  Premium|    F|    SI1| 60.4|   61|  342|3.88|3.84|2.33|
#  14| 0.31|    Ideal|    J|    SI2| 62.2|   54|  344|4.35|4.37|2.71|
#  15|  0.2|  Premium|    E|    SI2| 60.2|   62|  345|3.79|3.75|2.27|
#  16| 0.32|  Premium|    E|     I1| 60.9|   58|  345|4.38|4.42|2.68|
#  17|  0.3|    Ideal|    I|    SI2|   62|   54|  348|4.31|4.34|2.68|
#  18|  0.3|     Good|    J|    SI1| 63.4|   54|  351|4.23|4.29| 2.7|
#  19|  0.3|     Good|    J|    SI1| 63.8|   56|  351|4.23|4.26|2.71|
#  20|  0.3|Very Good|    J|    SI1| 62.7|   59|  351|4.21|4.27|2.66|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# only showing top 20 rows
#
# </div>

# %%
df = spark.sql("SELECT * FROM diamonds")
df.summary().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-------+------------------+------------------+---------+-----+-------+------------------+------------------+-----------------+------------------+------------------+------------------+
# summary|               _c0|             carat|      cut|color|clarity|             depth|             table|            price|                 x|                 y|                 z|
# +-------+------------------+------------------+---------+-----+-------+------------------+------------------+-----------------+------------------+------------------+------------------+
#   count|             53940|             53940|    53940|53940|  53940|             53940|             53940|            53940|             53940|             53940|             53940|
#    mean|           26970.5|0.7979397478679852|     null| null|   null| 61.74940489432624| 57.45718390804603|3932.799721913237| 5.731157211716609| 5.734525954764462|3.5387337782723316|
#  stddev|15571.281096942537|0.4740112444054196|     null| null|   null|1.4326213188336525|2.2344905628213247|3989.439738146397|1.1217607467924915|1.1421346741235616|0.7056988469499883|
#     min|                 1|               0.2|     Fair|    D|     I1|                43|                43|             1000|                 0|                 0|                 0|
#     25%|           13482.0|               0.4|     null| null|   null|              61.0|              56.0|            950.0|              4.71|              4.72|              2.91|
#     50%|           26966.0|               0.7|     null| null|   null|              61.8|              57.0|           2401.0|               5.7|              5.71|              3.53|
#     75%|           40451.0|              1.04|     null| null|   null|              62.5|              59.0|           5324.0|              6.54|              6.54|              4.04|
#     max|              9999|              5.01|Very Good|    J|   VVS2|                79|                95|             9999|              9.86|              9.94|              8.06|
# +-------+------------------+------------------+---------+-----+-------+------------------+------------------+-----------------+------------------+------------------+------------------+
#
# </div>

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>diamonds</td><td>false</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
