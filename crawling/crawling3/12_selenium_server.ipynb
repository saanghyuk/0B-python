# %% [markdown]
# ### 주의
#
# <font color="red">해당 코드는 개인 컴퓨터의 jupyter notebook 이 아닌 ec2 서버의 jupyter notebook 에서 실행해주세요.</font>

# %%
from selenium import webdriver
from PIL import Image as pil

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("window=size=1920x1080")
driver = webdriver.Chrome(options=options)

# %%
driver.get("https://naver.com")
driver.save_screenshot("naver_main.png")
driver.quit()

# %%
# 저장한 이미지 확인
pil_im = pil.open("naver_main.png")
pil_im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x27D6E8083C8>
