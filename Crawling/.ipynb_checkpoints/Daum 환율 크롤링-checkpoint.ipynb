# %% [markdown]
# ## Daum 에서 환율 정보 크롤링
# ### 클립명 : SQL quiz_requests 2_pygsheets_20191108_04
#
# - https://finance.daum.net/exchanges
# - fake_useragent
#     - pip install fake_useragent

# %%
import requests
import pandas as pd

# %%
url = "https://finance.daum.net/api/exchanges/summaries"
response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
# 위 403 에러를 해결하기 위해 아래와 같이 작성합니다.

# %%
# !pip install fake_useragent
# Out:
# Collecting fake_useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\challenge\AppData\Local\pip\Cache\wheels\5e\63\09\d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built fake-useragent
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11

# %%
from fake_useragent import UserAgent

# %%
# 첫 로드가 느릴 수 있습니다. 기다려주세요.
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Windows NT 4.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36'

# %%
url = "https://finance.daum.net/api/exchanges/summaries"
headers = {
    "user-agent": UserAgent().chrome,
    "referer": "https://finance.daum.net/exchanges",
}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': [{'symbolCode': 'FRX.KRWUSD',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'USD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '미국',
#    'region': {'korName': '아메리카', 'engName': 'America'},
#    'name': '미국 (KRW/USD)',
#    'recurrenceCount': 233,
#    'basePrice': 1117.5,
#    'change': 'FALL',
#    'changePrice': 1.5,
#    'changeRate': 0.0013404826,
#    'cashBuyingPrice': 1137.05,
#    'cashSellingPrice': 1097.95,
#    'ttBuyingPrice': 1106.6,
#    'ttSellingPrice': 1128.4,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 1.9603,
#    'usDollarRate': 1.0,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWUSD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWUSD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWUSD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWUSD.png'}},
#   {'symbolCode': 'FRX.KRWJPY',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'JPY',
#    'currencyName': '엔',
#    'currencyUnit': 100,
#    'country': '일본',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '일본 (KRW/JPY100)',
#    'recurrenceCount': 233,
#    'basePrice': 1034.43,
#    'change': 'FALL',
#    'changePrice': 0.67,
#    'changeRate': 0.0006472805,
#    'cashBuyingPrice': 1052.53,
#    'cashSellingPrice': 1016.33,
#    'ttBuyingPrice': 1024.3,
#    'ttSellingPrice': 1044.56,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 1.902,
#    'usDollarRate': 0.9257,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWJPY.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWJPY.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWJPY.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWJPY.png'}},
#   {'symbolCode': 'FRX.KRWCNY',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'CNY',
#    'currencyName': '위안',
#    'currencyUnit': 1,
#    'country': '중국',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '중국 (KRW/CNY)',
#    'recurrenceCount': 233,
#    'basePrice': 172.23,
#    'change': 'EVEN',
#    'changePrice': 0.0,
#    'changeRate': 0,
#    'cashBuyingPrice': 180.84,
#    'cashSellingPrice': 163.62,
#    'ttBuyingPrice': 170.51,
#    'ttSellingPrice': 173.95,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 4.9784,
#    'usDollarRate': 0.1541,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWCNY.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWCNY.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWCNY.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWCNY.png'}},
#   {'symbolCode': 'FRX.KRWEUR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'EUR',
#    'currencyName': '유로',
#    'currencyUnit': 1,
#    'country': '유로',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '유로 (KRW/EUR)',
#    'recurrenceCount': 233,
#    'basePrice': 1346.03,
#    'change': 'RISE',
#    'changePrice': 2.67,
#    'changeRate': 0.0019875536,
#    'cashBuyingPrice': 1372.81,
#    'cashSellingPrice': 1319.25,
#    'ttBuyingPrice': 1332.57,
#    'ttSellingPrice': 1359.49,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 1.4014,
#    'usDollarRate': 1.2045,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWEUR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWEUR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWEUR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWEUR.png'}},
#   {'symbolCode': 'FRX.KRWGBP',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'GBP',
#    'currencyName': '파운드',
#    'currencyUnit': 1,
#    'country': '영국',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '영국 (KRW/GBP)',
#    'recurrenceCount': 233,
#    'basePrice': 1552.82,
#    'change': 'FALL',
#    'changePrice': 6.06,
#    'changeRate': 0.0038874063,
#    'cashBuyingPrice': 1583.41,
#    'cashSellingPrice': 1522.23,
#    'ttBuyingPrice': 1537.3,
#    'ttSellingPrice': 1568.34,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.023,
#    'usDollarRate': 1.3895,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWGBP.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWGBP.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWGBP.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWGBP.png'}},
#   {'symbolCode': 'FRX.KRWCHF',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'CHF',
#    'currencyName': '프랑',
#    'currencyUnit': 1,
#    'country': '스위스',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '스위스 (KRW/CHF)',
#    'recurrenceCount': 233,
#    'basePrice': 1220.51,
#    'change': 'RISE',
#    'changePrice': 1.56,
#    'changeRate': 0.00127979,
#    'cashBuyingPrice': 1244.55,
#    'cashSellingPrice': 1196.47,
#    'ttBuyingPrice': 1208.31,
#    'ttSellingPrice': 1232.71,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 1.1762,
#    'usDollarRate': 1.0922,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWCHF.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWCHF.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWCHF.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWCHF.png'}},
#   {'symbolCode': 'FRX.KRWCAD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'CAD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '캐나다',
#    'region': {'korName': '아메리카', 'engName': 'America'},
#    'name': '캐나다 (KRW/CAD)',
#    'recurrenceCount': 233,
#    'basePrice': 893.5,
#    'change': 'RISE',
#    'changePrice': 4.91,
#    'changeRate': 0.005525608,
#    'cashBuyingPrice': 911.1,
#    'cashSellingPrice': 875.9,
#    'ttBuyingPrice': 884.57,
#    'ttSellingPrice': 902.43,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.355,
#    'usDollarRate': 0.7996,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWCAD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWCAD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWCAD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWCAD.png'}},
#   {'symbolCode': 'FRX.KRWNZD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'NZD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '뉴질랜드',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '뉴질랜드 (KRW/NZD)',
#    'recurrenceCount': 233,
#    'basePrice': 802.7,
#    'change': 'FALL',
#    'changePrice': 0.85,
#    'changeRate': 0.001057806,
#    'cashBuyingPrice': 818.51,
#    'cashSellingPrice': 786.89,
#    'ttBuyingPrice': 794.68,
#    'ttSellingPrice': 810.72,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.455,
#    'usDollarRate': 0.7183,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWNZD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWNZD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWNZD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWNZD.png'}},
#   {'symbolCode': 'FRX.KRWHKD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'HKD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '홍콩',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '홍콩 (KRW/HKD)',
#    'recurrenceCount': 233,
#    'basePrice': 144.01,
#    'change': 'FALL',
#    'changePrice': 0.12,
#    'changeRate': 0.0008325817,
#    'cashBuyingPrice': 146.84,
#    'cashSellingPrice': 141.18,
#    'ttBuyingPrice': 142.57,
#    'ttSellingPrice': 145.45,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.065,
#    'usDollarRate': 0.1289,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWHKD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWHKD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWHKD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWHKD.png'}},
#   {'symbolCode': 'FRX.KRWBRL',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'BRL',
#    'currencyName': '레알',
#    'currencyUnit': 1,
#    'country': '브라질',
#    'region': {'korName': '아메리카', 'engName': 'America'},
#    'name': '브라질 (KRW/BRL)',
#    'recurrenceCount': 233,
#    'basePrice': 200.65,
#    'change': 'FALL',
#    'changePrice': 0.28,
#    'changeRate': 0.0013935201,
#    'cashBuyingPrice': 221.11,
#    'cashSellingPrice': 184.6,
#    'ttBuyingPrice': 198.25,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 4.949,
#    'usDollarRate': 0.1796,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWBRL.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWBRL.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWBRL.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWBRL.png'}},
#   {'symbolCode': 'FRX.KRWMXN',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'MXN',
#    'currencyName': '페소',
#    'currencyUnit': 1,
#    'country': '멕시코',
#    'region': {'korName': '아메리카', 'engName': 'America'},
#    'name': '멕시코 (KRW/MXN)',
#    'recurrenceCount': 233,
#    'basePrice': 56.05,
#    'change': 'FALL',
#    'changePrice': 0.02,
#    'changeRate': 0.000356697,
#    'cashBuyingPrice': 61.65,
#    'cashSellingPrice': 51.35,
#    'ttBuyingPrice': 55.49,
#    'ttSellingPrice': 56.61,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 6.362,
#    'usDollarRate': 0.0502,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWMXN.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWMXN.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWMXN.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWMXN.png'}},
#   {'symbolCode': 'FRX.KRWAED',
#    'date': '2021-04-22 20:02:30',
#    'currencyCode': 'AED',
#    'currencyName': '디르함',
#    'currencyUnit': 1,
#    'country': '아랍에미리트',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '아랍에미리트 (KRW/AED)',
#    'recurrenceCount': 233,
#    'basePrice': 304.23,
#    'change': 'FALL',
#    'changePrice': 0.41,
#    'changeRate': 0.0013458508,
#    'cashBuyingPrice': 320.96,
#    'cashSellingPrice': 283.24,
#    'ttBuyingPrice': 301.19,
#    'ttSellingPrice': 307.27,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.245,
#    'usDollarRate': 0.2722,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWAED.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWAED.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWAED.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWAED.png'}},
#   {'symbolCode': 'FRX.KRWKWD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'KWD',
#    'currencyName': '디나르',
#    'currencyUnit': 1,
#    'country': '쿠웨이트',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '쿠웨이트 (KRW/KWD)',
#    'recurrenceCount': 233,
#    'basePrice': 3710.65,
#    'change': 'FALL',
#    'changePrice': 4.74,
#    'changeRate': 0.0012757745,
#    'cashBuyingPrice': 3951.84,
#    'cashSellingPrice': 3413.8,
#    'ttBuyingPrice': 3673.55,
#    'ttSellingPrice': 3747.75,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 3.095,
#    'usDollarRate': 3.3205,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWKWD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWKWD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWKWD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWKWD.png'}},
#   {'symbolCode': 'FRX.KRWBHD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'BHD',
#    'currencyName': '디나르',
#    'currencyUnit': 1,
#    'country': '바레인',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '바레인 (KRW/BHD)',
#    'recurrenceCount': 233,
#    'basePrice': 2964.27,
#    'change': 'FALL',
#    'changePrice': 3.98,
#    'changeRate': 0.0013408574,
#    'cashBuyingPrice': 3153.98,
#    'cashSellingPrice': 2727.13,
#    'ttBuyingPrice': 2934.63,
#    'ttSellingPrice': 2993.91,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 3.575,
#    'usDollarRate': 2.6526,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWBHD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWBHD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWBHD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWBHD.png'}},
#   {'symbolCode': 'FRX.KRWINR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'INR',
#    'currencyName': '루피',
#    'currencyUnit': 1,
#    'country': '인도',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '인도 (KRW/INR)',
#    'recurrenceCount': 233,
#    'basePrice': 14.89,
#    'change': 'RISE',
#    'changePrice': 0.06,
#    'changeRate': 0.004045853,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 5.685,
#    'usDollarRate': 0.0133,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWINR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWINR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWINR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWINR.png'}},
#   {'symbolCode': 'FRX.KRWSAR',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'SAR',
#    'currencyName': '리얄',
#    'currencyUnit': 1,
#    'country': '사우디',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '사우디 (KRW/SAR)',
#    'recurrenceCount': 233,
#    'basePrice': 297.98,
#    'change': 'FALL',
#    'changePrice': 0.4,
#    'changeRate': 0.0013405724,
#    'cashBuyingPrice': 316.75,
#    'cashSellingPrice': 277.42,
#    'ttBuyingPrice': 295.01,
#    'ttSellingPrice': 300.95,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.565,
#    'usDollarRate': 0.2666,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWSAR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWSAR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWSAR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWSAR.png'}},
#   {'symbolCode': 'FRX.KRWNOK',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'NOK',
#    'currencyName': '크로네',
#    'currencyUnit': 1,
#    'country': '노르웨이',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '노르웨이 (KRW/NOK)',
#    'recurrenceCount': 233,
#    'basePrice': 134.11,
#    'change': 'RISE',
#    'changePrice': 0.46,
#    'changeRate': 0.0034418257,
#    'cashBuyingPrice': 137.39,
#    'cashSellingPrice': 130.83,
#    'ttBuyingPrice': 132.77,
#    'ttSellingPrice': 135.45,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.275,
#    'usDollarRate': 0.12,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWNOK.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWNOK.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWNOK.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWNOK.png'}},
#   {'symbolCode': 'FRX.KRWDKK',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'DKK',
#    'currencyName': '크로나',
#    'currencyUnit': 1,
#    'country': '덴마크',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '덴마크 (KRW/DKK)',
#    'recurrenceCount': 233,
#    'basePrice': 180.99,
#    'change': 'RISE',
#    'changePrice': 0.35,
#    'changeRate': 0.0019375554,
#    'cashBuyingPrice': 185.42,
#    'cashSellingPrice': 176.56,
#    'ttBuyingPrice': 179.19,
#    'ttSellingPrice': 182.79,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 1.875,
#    'usDollarRate': 0.162,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWDKK.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWDKK.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWDKK.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWDKK.png'}},
#   {'symbolCode': 'FRX.KRWMYR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'MYR',
#    'currencyName': '링키트',
#    'currencyUnit': 1,
#    'country': '말레이시아',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '말레이시아 (KRW/MYR)',
#    'recurrenceCount': 233,
#    'basePrice': 271.73,
#    'change': 'RISE',
#    'changePrice': 0.19,
#    'changeRate': 0.0006997127,
#    'cashBuyingPrice': 288.84,
#    'cashSellingPrice': 251.63,
#    'ttBuyingPrice': 269.02,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 3.815,
#    'usDollarRate': 0.2432,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWMYR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWMYR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWMYR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWMYR.png'}},
#   {'symbolCode': 'FRX.KRWBDT',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'BDT',
#    'currencyName': '타카',
#    'currencyUnit': 1,
#    'country': '방글라데시',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '방글라데시 (KRW/BDT)',
#    'recurrenceCount': 233,
#    'basePrice': 13.18,
#    'change': 'FALL',
#    'changePrice': 0.02,
#    'changeRate': 0.0015151515,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 5.0649,
#    'usDollarRate': 0.0118,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWBDT.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWBDT.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWBDT.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWBDT.png'}},
#   {'symbolCode': 'FRX.KRWPKR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'PKR',
#    'currencyName': '루피',
#    'currencyUnit': 1,
#    'country': '파키스탄',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '파키스탄 (KRW/PKR)',
#    'recurrenceCount': 233,
#    'basePrice': 7.28,
#    'change': 'FALL',
#    'changePrice': 0.02,
#    'changeRate': 0.002739726,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 9.175,
#    'usDollarRate': 0.0065,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWPKR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWPKR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWPKR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWPKR.png'}},
#   {'symbolCode': 'FRX.KRWIDR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'IDR',
#    'currencyName': '루피아',
#    'currencyUnit': 100,
#    'country': '인도네시아',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '인도네시아 (KRW/IDR100)',
#    'recurrenceCount': 233,
#    'basePrice': 7.71,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'changeRate': 0.0012953368,
#    'cashBuyingPrice': 8.24,
#    'cashSellingPrice': 6.94,
#    'ttBuyingPrice': 7.64,
#    'ttSellingPrice': 7.78,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 5.525,
#    'usDollarRate': 0.0069,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWIDR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWIDR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWIDR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWIDR.png'}},
#   {'symbolCode': 'FRX.KRWTWD',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'TWD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '대만',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '대만 (KRW/TWD)',
#    'recurrenceCount': 233,
#    'basePrice': 39.77,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'changeRate': 0.0002513826,
#    'cashBuyingPrice': 44.97,
#    'cashSellingPrice': 36.99,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.395,
#    'usDollarRate': 0.0356,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWTWD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWTWD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWTWD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWTWD.png'}},
#   {'symbolCode': 'FRX.KRWPHP',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'PHP',
#    'currencyName': '페소',
#    'currencyUnit': 1,
#    'country': '필리핀',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '필리핀 (KRW/PHP)',
#    'recurrenceCount': 233,
#    'basePrice': 23.09,
#    'change': 'FALL',
#    'changePrice': 0.03,
#    'changeRate': 0.0012975779,
#    'cashBuyingPrice': 25.39,
#    'cashSellingPrice': 21.2,
#    'ttBuyingPrice': 22.86,
#    'ttSellingPrice': 23.32,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 3.002,
#    'usDollarRate': 0.0207,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWPHP.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWPHP.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWPHP.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWPHP.png'}},
#   {'symbolCode': 'FRX.KRWSEK',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'SEK',
#    'currencyName': '크로나',
#    'currencyUnit': 1,
#    'country': '스웨덴',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '스웨덴 (KRW/SEK)',
#    'recurrenceCount': 233,
#    'basePrice': 132.98,
#    'change': 'RISE',
#    'changePrice': 0.89,
#    'changeRate': 0.0067378303,
#    'cashBuyingPrice': 136.23,
#    'cashSellingPrice': 129.73,
#    'ttBuyingPrice': 131.66,
#    'ttSellingPrice': 134.3,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.025,
#    'usDollarRate': 0.119,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWSEK.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWSEK.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWSEK.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWSEK.png'}},
#   {'symbolCode': 'FRX.KRWAUD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'AUD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '호주',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '호주 (KRW/AUD)',
#    'recurrenceCount': 233,
#    'basePrice': 865.17,
#    'change': 'RISE',
#    'changePrice': 1.19,
#    'changeRate': 0.0013773467,
#    'cashBuyingPrice': 882.21,
#    'cashSellingPrice': 848.13,
#    'ttBuyingPrice': 856.52,
#    'ttSellingPrice': 873.82,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.115,
#    'usDollarRate': 0.7742,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWAUD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWAUD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWAUD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWAUD.png'}},
#   {'symbolCode': 'FRX.KRWSGD',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'SGD',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '싱가포르',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '싱가포르 (KRW/SGD)',
#    'recurrenceCount': 233,
#    'basePrice': 841.46,
#    'change': 'RISE',
#    'changePrice': 0.26,
#    'changeRate': 0.0003090823,
#    'cashBuyingPrice': 858.2,
#    'cashSellingPrice': 824.72,
#    'ttBuyingPrice': 833.05,
#    'ttSellingPrice': 849.87,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.255,
#    'usDollarRate': 0.753,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWSGD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWSGD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWSGD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWSGD.png'}},
#   {'symbolCode': 'FRX.KRWTHB',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'THB',
#    'currencyName': '바트',
#    'currencyUnit': 1,
#    'country': '태국',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '태국 (KRW/THB)',
#    'recurrenceCount': 233,
#    'basePrice': 35.65,
#    'change': 'FALL',
#    'changePrice': 0.04,
#    'changeRate': 0.0011207621,
#    'cashBuyingPrice': 37.43,
#    'cashSellingPrice': 33.52,
#    'ttBuyingPrice': 35.3,
#    'ttSellingPrice': 36.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.525,
#    'usDollarRate': 0.0319,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWTHB.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWTHB.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWTHB.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWTHB.png'}},
#   {'symbolCode': 'FRX.KRWEGP',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'EGP',
#    'currencyName': '파운드',
#    'currencyUnit': 1,
#    'country': '이집트',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '이집트 (KRW/EGP)',
#    'recurrenceCount': 233,
#    'basePrice': 71.13,
#    'change': 'FALL',
#    'changePrice': 0.23,
#    'changeRate': 0.0032230942,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 7.225,
#    'usDollarRate': 0.0637,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWEGP.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWEGP.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWEGP.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWEGP.png'}},
#   {'symbolCode': 'FRX.KRWBND',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'BND',
#    'currencyName': '달러',
#    'currencyUnit': 1,
#    'country': '브루나이',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '브루나이 (KRW/BND)',
#    'recurrenceCount': 233,
#    'basePrice': 841.46,
#    'change': 'RISE',
#    'changePrice': 0.26,
#    'changeRate': 0.0003090823,
#    'cashBuyingPrice': 875.11,
#    'cashSellingPrice': 790.98,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.255,
#    'usDollarRate': 0.753,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWBND.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWBND.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWBND.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWBND.png'}},
#   {'symbolCode': 'FRX.KRWILS',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'ILS',
#    'currencyName': '쉐캐림',
#    'currencyUnit': 1,
#    'country': '이스라엘',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '이스라엘 (KRW/ILS)',
#    'recurrenceCount': 233,
#    'basePrice': 342.55,
#    'change': 'FALL',
#    'changePrice': 0.99,
#    'changeRate': 0.0028817605,
#    'cashBuyingPrice': 376.8,
#    'cashSellingPrice': 315.15,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.155,
#    'usDollarRate': 0.3065,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWILS.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWILS.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWILS.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWILS.png'}},
#   {'symbolCode': 'FRX.KRWJOD',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'JOD',
#    'currencyName': '디나르',
#    'currencyUnit': 1,
#    'country': '요르단',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '요르단 (KRW/JOD)',
#    'recurrenceCount': 233,
#    'basePrice': 1576.16,
#    'change': 'FALL',
#    'changePrice': 2.12,
#    'changeRate': 0.0013432344,
#    'cashBuyingPrice': 1716.43,
#    'cashSellingPrice': 1450.07,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 5.443,
#    'usDollarRate': 1.4104,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWJOD.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWJOD.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWJOD.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWJOD.png'}},
#   {'symbolCode': 'FRX.KRWVND',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'VND',
#    'currencyName': '동',
#    'currencyUnit': 100,
#    'country': '베트남',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '베트남 (KRW/VND100)',
#    'recurrenceCount': 233,
#    'basePrice': 4.84,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'changeRate': 0.0020618557,
#    'cashBuyingPrice': 5.41,
#    'cashSellingPrice': 4.27,
#    'ttBuyingPrice': 4.8,
#    'ttSellingPrice': 4.88,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.875,
#    'usDollarRate': 0.0043,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWVND.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWVND.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWVND.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWVND.png'}},
#   {'symbolCode': 'FRX.KRWRUB',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'RUB',
#    'currencyName': '루블',
#    'currencyUnit': 1,
#    'country': '러시아',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '러시아 (KRW/RUB)',
#    'recurrenceCount': 233,
#    'basePrice': 14.66,
#    'change': 'RISE',
#    'changePrice': 0.06,
#    'changeRate': 0.004109589,
#    'cashBuyingPrice': 15.68,
#    'cashSellingPrice': 13.05,
#    'ttBuyingPrice': 14.52,
#    'ttSellingPrice': 14.8,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 6.975,
#    'usDollarRate': 0.0131,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWRUB.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWRUB.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWRUB.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWRUB.png'}},
#   {'symbolCode': 'FRX.KRWHUF',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'HUF',
#    'currencyName': '포린트',
#    'currencyUnit': 1,
#    'country': '헝가리',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '헝가리 (KRW/HUF)',
#    'recurrenceCount': 233,
#    'basePrice': 3.7,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'changeRate': 0.0026954178,
#    'cashBuyingPrice': 4.04,
#    'cashSellingPrice': 3.41,
#    'ttBuyingPrice': 3.66,
#    'ttSellingPrice': 3.74,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.805,
#    'usDollarRate': 0.0033,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWHUF.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWHUF.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWHUF.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWHUF.png'}},
#   {'symbolCode': 'FRX.KRWPLN',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'PLN',
#    'currencyName': '줄러티',
#    'currencyUnit': 1,
#    'country': '폴란드',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '폴란드 (KRW/PLN)',
#    'recurrenceCount': 233,
#    'basePrice': 295.32,
#    'change': 'RISE',
#    'changePrice': 0.53,
#    'changeRate': 0.00179789,
#    'cashBuyingPrice': 318.94,
#    'cashSellingPrice': 271.7,
#    'ttBuyingPrice': 292.08,
#    'ttSellingPrice': 298.56,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.125,
#    'usDollarRate': 0.2643,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWPLN.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWPLN.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWPLN.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWPLN.png'}},
#   {'symbolCode': 'FRX.KRWZAR',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'ZAR',
#    'currencyName': '랜드',
#    'currencyUnit': 1,
#    'country': '남아공',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '남아공 (KRW/ZAR)',
#    'recurrenceCount': 233,
#    'basePrice': 78.23,
#    'change': 'FALL',
#    'changePrice': 0.09,
#    'changeRate': 0.0011491318,
#    'cashBuyingPrice': 82.92,
#    'cashSellingPrice': 71.98,
#    'ttBuyingPrice': 77.3,
#    'ttSellingPrice': 79.16,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 6.935,
#    'usDollarRate': 0.07,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWZAR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWZAR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWZAR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWZAR.png'}},
#   {'symbolCode': 'FRX.KRWMNT',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'MNT',
#    'currencyName': '투그릭',
#    'currencyUnit': 1,
#    'country': '몽골',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '몽골 (KRW/MNT)',
#    'recurrenceCount': 233,
#    'basePrice': 0.39,
#    'change': 'EVEN',
#    'changePrice': 0.0,
#    'changeRate': 0,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 13.475,
#    'usDollarRate': 0.0003,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWMNT.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWMNT.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWMNT.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWMNT.png'}},
#   {'symbolCode': 'FRX.KRWCZK',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'CZK',
#    'currencyName': '코루나',
#    'currencyUnit': 1,
#    'country': '체코',
#    'region': {'korName': '유럽', 'engName': 'Europe'},
#    'name': '체코 (KRW/CZK)',
#    'recurrenceCount': 233,
#    'basePrice': 52.07,
#    'change': 'RISE',
#    'changePrice': 0.21,
#    'changeRate': 0.0040493637,
#    'cashBuyingPrice': 56.49,
#    'cashSellingPrice': 47.39,
#    'ttBuyingPrice': 51.5,
#    'ttSellingPrice': 52.64,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.325,
#    'usDollarRate': 0.0466,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWCZK.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWCZK.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWCZK.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWCZK.png'}},
#   {'symbolCode': 'FRX.KRWKZT',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'KZT',
#    'currencyName': '텡게',
#    'currencyUnit': 1,
#    'country': '카자흐스탄',
#    'region': {'korName': '아시아', 'engName': 'Asia'},
#    'name': '카자흐스탄 (KRW/KZT)',
#    'recurrenceCount': 233,
#    'basePrice': 2.58,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'changeRate': 0.0038610039,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 13.475,
#    'usDollarRate': 0.0023,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWKZT.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWKZT.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWKZT.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWKZT.png'}},
#   {'symbolCode': 'FRX.KRWQAR',
#    'date': '2021-04-22 20:02:31',
#    'currencyCode': 'QAR',
#    'currencyName': '리얄',
#    'currencyUnit': 1,
#    'country': '카타르',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '카타르 (KRW/QAR)',
#    'recurrenceCount': 233,
#    'basePrice': 306.89,
#    'change': 'FALL',
#    'changePrice': 0.44,
#    'changeRate': 0.0014316858,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 0.0,
#    'ttSellingPrice': 0.0,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 2.225,
#    'usDollarRate': 0.2746,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWQAR.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWQAR.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWQAR.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWQAR.png'}},
#   {'symbolCode': 'FRX.KRWTRY',
#    'date': '2021-04-22 20:02:32',
#    'currencyCode': 'TRY',
#    'currencyName': '리라',
#    'currencyUnit': 1,
#    'country': '터키',
#    'region': {'korName': '중동', 'engName': 'Middle East'},
#    'name': '터키 (KRW/TRY)',
#    'recurrenceCount': 233,
#    'basePrice': 135.23,
#    'change': 'FALL',
#    'changePrice': 1.22,
#    'changeRate': 0.008941004,
#    'cashBuyingPrice': 0.0,
#    'cashSellingPrice': 0.0,
#    'ttBuyingPrice': 133.75,
#    'ttSellingPrice': 136.71,
#    'tcBuyingPrice': None,
#    'fcSellingPrice': None,
#    'exchangeCommission': 20.475,
#    'usDollarRate': 0.121,
#    'chartImageUrl': {'day': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/d/FRX.KRWTRY.png',
#     'month': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m/FRX.KRWTRY.png',
#     'month3': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/m3/FRX.KRWTRY.png',
#     'year': 'https://t1.daumcdn.net/finance/chart/kr/daumforex/y/FRX.KRWTRY.png'}}],
#  'baseDate': '2021-04-22 20:02:30',
#  'recurrenceCount': 233,
#  'provider': '하나은행'}

# %%
data = response.json()["data"]
result_df = pd.DataFrame(data)
result_df.head(2)
# Out:
#    basePrice  cashBuyingPrice  cashSellingPrice change  changePrice  \
# 0    1117.50          1137.05           1097.95   FALL         1.50
# 1    1034.43          1052.53           1016.33   FALL         0.67
#
#    changeRate                                      chartImageUrl country  \
# 0    0.001340  {'day': 'https://t1.daumcdn.net/finance/chart/...      미국
# 1    0.000647  {'day': 'https://t1.daumcdn.net/finance/chart/...      일본
#
#   currencyCode currencyName  ...  exchangeCommission fcSellingPrice  \
# 0          USD           달러  ...              1.9603           None
# 1          JPY            엔  ...              1.9020           None
#
#               name recurrenceCount                                     region  \
# 0     미국 (KRW/USD)             233  {'korName': '아메리카', 'engName': 'America'}
# 1  일본 (KRW/JPY100)             233      {'korName': '아시아', 'engName': 'Asia'}
#
#    symbolCode tcBuyingPrice ttBuyingPrice ttSellingPrice  usDollarRate
# 0  FRX.KRWUSD          None        1106.6        1128.40        1.0000
# 1  FRX.KRWJPY          None        1024.3        1044.56        0.9257
#
# [2 rows x 22 columns]
