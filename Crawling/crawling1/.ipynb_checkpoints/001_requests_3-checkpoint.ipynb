# %% [markdown]
# ### web crawling
# - 웹 서비스의 구조 : 서버 - 클라이언트
# - 크롤링 방법 세가지
#     - requests : json (동적 페이지)
#         - 동적 페이지(URL의 변경 없이 데이터를 수정 및 추가)
#         - 네이버 주식 사이트에서 주가 데이터 크롤링
#             - 시각화(정규화), 상관계수
#     - requests: html 정적 페이지
#         - URL 변경으로 데이터를 수정 및 추가
#     - selenium : webdriver
#         - 1, 2번 방법을 사용하지 못할 때 사용
#         - 거의 모든 것을 다 할 수 있으나, 실제 해야되서 느릴 수 밖에 없다는 단점이 있다.
#
#
# - 크롤링 절차
#     - 웹서비스 분석 : URL
#     - 요청, 응답 : str
#     - str 데이터 파싱(dict, bs obj(css-selector)) 후 데이터 프레임으로 생성

# %% [markdown]
# ## Zigbang 데이터 크롤링
# - 동 이름을 입력하면 아파트 매물을 데이터 프레임으로 만들기
# - robots.txt 현재는 disallow 되어 있음

# %% [markdown]
# 1. 웹서비스 분석 : URL 찾기, 크롤링 전략 세우기
# - 동 이름 입력 -> lat, lng
# - lat, lng -> geohash : geohash 패키지 설치
# - geohash -> item ids
# - item ids -> item datas(데이터 프레임)

# %%
import requests

# %%
# 동이름 -> 위도 경도
addr = "성수동"
serviceType = "아파트"
url = "https://apis.zigbang.com/v2/search?leaseYn=N&q={}&serviceType={}".format(addr, serviceType)

response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"]
lat, lng
# Out:
# (37.541725158691406, 127.04335021972656)

# %%
# 위도, 경도 -> geohash
# pip install geohash2

# %%
# !pip install geohash2
# Out:
# Collecting geohash2
#   Downloading https://files.pythonhosted.org/packages/3e/0d/c40ea785cc5fa33c2f1e796ee02e763207140542d7aae2c6ea413358c092/geohash2-1.1.tar.gz
# Requirement already satisfied: docutils>=0.3 in c:\users\challenge\anaconda3\lib\site-packages (from geohash2) (0.14)
# Building wheels for collected packages: geohash2
#   Building wheel for geohash2 (setup.py): started
#   Building wheel for geohash2 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\challenge\AppData\Local\pip\Cache\wheels\69\63\0d\560a1741fa3f0ab897105cddb33f21f38c3330e4a57ea75db6
# Successfully built geohash2
# Installing collected packages: geohash2
# Successfully installed geohash2-1.1

# %%
import geohash2

# %%
# precision : 작을수록 큰범위, 클수록 작은 범위
geohash = geohash2.encode(lat, lng, precision=5)
lat, lng, geohash
# Out:
# (37.541725158691406, 127.04335021972656, 'wydmd')

# %%
# geohash -> ids
url = "https://apis.zigbang.com/property/apartments/items?domain=zigbang&geohash={}&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
response = requests.get(url)
datas = response.json()["items"]
ids = [data["itemId"] for data in datas]
len(data), ids[:3]
# Out:
# (615, [26979147, 26978981, 26978950])

# %%
data[0]
# Out:
# {'itemId': 26979147,
#  'lat': 37.5688608776878,
#  'lng': 127.02794524824768,
#  'created_at': '2021-04-22 15:02:08'}

# %%
ids_str = str(ids[:200]).replace(" ", "")

# %%
# ids -> items
ids_str = str(ids[:200]).replace(" ", "")
url = "https://apis.zigbang.com/property/apartments/items?\
vritemIds={ids}&itemIds{ids}&citemIds={ids}".format(ids=ids_str)
response = requests.get(url)
datas = response.json()["items"]
datas
# Out:
# [{'itemId': 26979147,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장형.입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T08:04:11.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '103동',
#   'roomTypeId': 19810,
#   'grossAreaName': {'m2': 160, 'p': 48},
#   'grossArea': {'m2': 160, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 129, 'p': 39},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 15:02:08',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 160, 'p': 48},
#   'isNew': True,
#   'sales': 195000},
#  {'itemId': 26978981,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '역세권.탁트인전망.임대안고입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T08:03:48.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '103동',
#   'roomTypeId': 19810,
#   'grossAreaName': {'m2': 160, 'p': 48},
#   'grossArea': {'m2': 160, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 129, 'p': 39},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:55:43',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 160, 'p': 48},
#   'isNew': True,
#   'sales': 190000},
#  {'itemId': 26978950,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '8',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '역세권.판상형.에어컨',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T08:03:47.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '112동',
#   'roomTypeId': 149701,
#   'grossAreaName': {'m2': '109E', 'p': '32E'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149701/95c7e6154d4c458883ef773ab9cd7585.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:54:28',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149701/95c7e6154d4c458883ef773ab9cd7585.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '109E', 'p': '32E'},
#   'isNew': True,
#   'sales': 165000},
#  {'itemId': 26978404,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '판상형.에어컨',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:54:38.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '106동',
#   'roomTypeId': 19807,
#   'grossAreaName': {'m2': '110B', 'p': '33B'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19807/d97465860c3d47f48fc8fd20607dbacf.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:30:39',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19807/d97465860c3d47f48fc8fd20607dbacf.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110B', 'p': '33B'},
#   'isNew': True,
#   'sales': 167000},
#  {'itemId': 26978351,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨.판상형입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:54:29.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '108동',
#   'roomTypeId': 149701,
#   'grossAreaName': {'m2': '109E', 'p': '32E'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149701/95c7e6154d4c458883ef773ab9cd7585.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:28:30',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149701/95c7e6154d4c458883ef773ab9cd7585.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '109E', 'p': '32E'},
#   'isNew': True,
#   'sales': 175000},
#  {'itemId': 26978323,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '초역세권.에어컨',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:54:25.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '117동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:27:31',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 175000},
#  {'itemId': 26978296,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '17',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨.로얄동.판상형',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:59.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '113동',
#   'roomTypeId': 19808,
#   'grossAreaName': {'m2': '110D', 'p': '33D'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:26:34',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '110D', 'p': '33D'},
#   'isNew': True,
#   'sales': 175000},
#  {'itemId': 26978248,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장.에어컨6.입주가능',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:45.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '102동',
#   'roomTypeId': 19812,
#   'grossAreaName': {'m2': 179, 'p': 54},
#   'grossArea': {'m2': 179, 'p': 54},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 148, 'p': 44},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19812/f72d5e221d3546fabf2e6be92cbee2fa.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:24:23',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19812/f72d5e221d3546fabf2e6be92cbee2fa.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 179, 'p': 54},
#   'isNew': True,
#   'sales': 188000},
#  {'itemId': 26978213,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '역세권.에어컨.입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:13.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '121동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:22:50',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 160000},
#  {'itemId': 26978200,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '28',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨3,확장.지하쳘연결동입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:11.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '129동',
#   'roomTypeId': 149696,
#   'grossAreaName': {'m2': '83C', 'p': '25C'},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149696/57d1b34a78bc42a887ca5f367852d6d7.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:22:16',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149696/57d1b34a78bc42a887ca5f367852d6d7.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '83C', 'p': '25C'},
#   'isNew': True,
#   'sales': 149500},
#  {'itemId': 26978175,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,올확장,확트인전망의매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:05.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '213동',
#   'roomTypeId': 19231,
#   'grossAreaName': {'m2': '86A', 'p': '26A'},
#   'grossArea': {'m2': 86, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19231/7a563c1e688045d59f37baacb8200e8b.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:20:56',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19231/7a563c1e688045d59f37baacb8200e8b.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '86A', 'p': '26A'},
#   'isNew': True,
#   'sales': 140000},
#  {'itemId': 26978157,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '28',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '초역세권,에어컨,저렴한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:03.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '129동',
#   'roomTypeId': 149692,
#   'grossAreaName': {'m2': 57, 'p': 17},
#   'grossArea': {'m2': 57, 'p': 17},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 40, 'p': 12},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149692/a49e4bd335f7448fa8d0cc436f006fbf.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:20:17',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149692/a49e4bd335f7448fa8d0cc436f006fbf.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 57, 'p': 17},
#   'isNew': True,
#   'sales': 95000},
#  {'itemId': 26978140,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향.로얄동.입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:53:01.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '209동',
#   'roomTypeId': 19225,
#   'grossAreaName': {'m2': '109C', 'p': '32C'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19225/662fee5907194a6c96f6ffeb5d967958.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:19:29',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19225/662fee5907194a6c96f6ffeb5d967958.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109C', 'p': '32C'},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 26978129,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확징.입주가능.탁트인전망',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:56.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '203동',
#   'roomTypeId': 19224,
#   'grossAreaName': {'m2': '107A', 'p': '32A'},
#   'grossArea': {'m2': 107, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19224/ea7969ce4e614d71affc49338f864136.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:18:48',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19224/ea7969ce4e614d71affc49338f864136.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '107A', 'p': '32A'},
#   'isNew': True,
#   'sales': 172000},
#  {'itemId': 26978118,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨3,역세권,빠른입주가능합니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:52.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '116동',
#   'roomTypeId': 149710,
#   'grossAreaName': {'m2': 149, 'p': 45},
#   'grossArea': {'m2': 149, 'p': 45},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 115, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149710/82ff5bc438da4981ad2c7fe11896d48e.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:18:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149710/82ff5bc438da4981ad2c7fe11896d48e.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 149, 'p': 45},
#   'isNew': True,
#   'sales': 210000},
#  {'itemId': 26978095,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.57046508789063,
#   'lng': 127.02467346191406,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨3,확장,남향,입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:48.000Z',
#   'apartmentId': 22637,
#   'apartmentName': '텐즈힐2단지',
#   'buildingName': '211동',
#   'roomTypeId': 19225,
#   'grossAreaName': {'m2': '109C', 'p': '32C'},
#   'grossArea': {'m2': 109, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/22637/19225/662fee5907194a6c96f6ffeb5d967958.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:17:20',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/22637/19225/662fee5907194a6c96f6ffeb5d967958.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '109C', 'p': '32C'},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 26978061,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '초역세권,에어컨,최상의전망으로입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:38.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '117동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:15:57',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 180000},
#  {'itemId': 26978015,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55790135050871,
#   'lng': 127.02711722579186,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '대단지 역세권아파트. 거실폴딩도어 올수리집 입주가능',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:13.000Z',
#   'apartmentId': 5361,
#   'apartmentName': '행당대림',
#   'buildingName': '106동',
#   'roomTypeId': 8644,
#   'grossAreaName': {'m2': 104, 'p': 31},
#   'grossArea': {'m2': 104, 'p': 31},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5361/8644/123b4ce8a72f4aa783aed9541ae2e590.png',
#   'userNo': 3553010,
#   'agentId': 3553010,
#   'agentName': '거성공인중개사',
#   'agentTel': '0222984989',
#   'agentUserName': '김정의',
#   'agentPhone': '01085071969',
#   'created_at': '2021-04-22 14:13:52',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5361/8644/123b4ce8a72f4aa783aed9541ae2e590.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 104, 'p': 31},
#   'isNew': True,
#   'sales': 133000},
#  {'itemId': 26978010,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨4,확장,입주가능한매물입니다.',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:11.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '103동',
#   'roomTypeId': 149707,
#   'grossAreaName': {'m2': '111A', 'p': '33A'},
#   'grossArea': {'m2': 111, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:13:32',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149707/868c6b70f99e42709f761b02c10f21a5.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '111A', 'p': '33A'},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 26978005,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.553430107559,
#   'lng': 127.0357391828018,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전망동,거실확장,수리, 정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:09.000Z',
#   'apartmentId': 5645,
#   'apartmentName': '대림강변타운',
#   'buildingName': '104동',
#   'roomTypeId': 8955,
#   'grossAreaName': {'m2': '79A', 'p': '23A'},
#   'grossArea': {'m2': 79, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5645/8955/fcf8200f29bb456abeb9582bf6844ca3.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 14:13:14',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5645/8955/fcf8200f29bb456abeb9582bf6844ca3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '79A', 'p': '23A'},
#   'isNew': True,
#   'sales': 115000},
#  {'itemId': 26977979,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '에어컨6,더블역세권',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:52:06.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '103동',
#   'roomTypeId': 149710,
#   'grossAreaName': {'m2': 149, 'p': 45},
#   'grossArea': {'m2': 149, 'p': 45},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 115, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149710/82ff5bc438da4981ad2c7fe11896d48e.png',
#   'userNo': 4906352,
#   'agentId': 4906352,
#   'agentName': '센트라스리치공인중개사사무소',
#   'agentTel': '0222342201',
#   'agentUserName': '손수연',
#   'agentPhone': '01052395337',
#   'created_at': '2021-04-22 14:12:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149710/82ff5bc438da4981ad2c7fe11896d48e.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 149, 'p': 45},
#   'isNew': True,
#   'sales': 198000},
#  {'itemId': 26975026,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '18',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.544733216499736,
#   'lng': 127.02308858683004,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '필로티 높은 4층, 입주 협의, 확장',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T07:08:19.000Z',
#   'apartmentId': 12313,
#   'apartmentName': '서울숲푸르지오1차',
#   'buildingName': '118동',
#   'roomTypeId': 13002,
#   'grossAreaName': {'m2': 73, 'p': 22},
#   'grossArea': {'m2': 73, 'p': 22},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/12313/13002/86164b80d05246a1b2a3a064834c37a1.png',
#   'userNo': 76860,
#   'agentId': 76860,
#   'agentName': '열린공인중개사사무소',
#   'agentTel': '0222954949',
#   'agentUserName': '강도인',
#   'agentPhone': '01054330295',
#   'created_at': '2021-04-22 11:42:47',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/12313/13002/86164b80d05246a1b2a3a064834c37a1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 73, 'p': 22},
#   'isNew': True,
#   'sales': 142000},
#  {'itemId': 26973914,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5607485,
#   'lng': 127.024713,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능한매매,에어컨2,탁트인전망,채광과시원한개방감최고',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:46:53.000Z',
#   'apartmentId': 36892,
#   'apartmentName': '왕십리자이',
#   'buildingName': '106동',
#   'roomTypeId': 151602,
#   'grossAreaName': {'m2': '82C', 'p': '24C'},
#   'grossArea': {'m2': 82, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/36892/151602/a7f83e1ec90a4bf893fd5bdcb994a315.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 11:05:52',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/36892/151602/a7f83e1ec90a4bf893fd5bdcb994a315.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '82C', 'p': '24C'},
#   'isNew': True,
#   'sales': 125000},
#  {'itemId': 26973896,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5607485,
#   'lng': 127.024713,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주협의,확장형,채광과 시원한 개방감 좋아요',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:46:11.000Z',
#   'apartmentId': 36892,
#   'apartmentName': '왕십리자이',
#   'buildingName': '103동',
#   'roomTypeId': 151604,
#   'grossAreaName': {'m2': 112, 'p': 33},
#   'grossArea': {'m2': 112, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/36892/151604/3c177203e6c14a7d94b5b8b6c534eba1.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 11:05:04',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/36892/151604/3c177203e6c14a7d94b5b8b6c534eba1.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 112, 'p': 33},
#   'isNew': True,
#   'sales': 155000},
#  {'itemId': 26973668,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5655391,
#   'lng': 127.027069,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '더블역세권, 생활편리한동, 10월입주가, 갭투가',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:41:34.000Z',
#   'apartmentId': 33613,
#   'apartmentName': '센트라스',
#   'buildingName': '127동',
#   'roomTypeId': 149699,
#   'grossAreaName': {'m2': '88G', 'p': '26G'},
#   'grossArea': {'m2': 88, 'p': 26},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/33613/149699/8e90e69505094badb94c311397460308.png',
#   'userNo': 10804703,
#   'agentId': 10804703,
#   'agentName': '열린공인중개사사무소',
#   'agentTel': '0222567700',
#   'agentUserName': '김명옥',
#   'agentPhone': '01022259644',
#   'created_at': '2021-04-22 10:57:00',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/33613/149699/8e90e69505094badb94c311397460308.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '88G', 'p': '26G'},
#   'isNew': True,
#   'sales': 138000},
#  {'itemId': 26973457,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능,탁트인뷰,선호하는맞통풍구조,확장형',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:40:17.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '118동',
#   'roomTypeId': 19808,
#   'grossAreaName': {'m2': '110D', 'p': '33D'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:51:02',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110D', 'p': '33D'},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 26973108,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '급매,전세안고매매,확장형,중문,맞통풍구조,채광과개방감좋아요',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:29:16.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '118동',
#   'roomTypeId': 19813,
#   'grossAreaName': {'m2': '83A', 'p': '25A'},
#   'grossArea': {'m2': 83, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19813/7ea5e91d1c3c4f40a89dc79960f9b556.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:39:54',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19813/7ea5e91d1c3c4f40a89dc79960f9b556.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '83A', 'p': '25A'},
#   'isNew': True,
#   'sales': 142000},
#  {'itemId': 26972997,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '17',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '전세안고매매,에어컨,확장형,판상형,맞통풍구조',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:28:30.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '113동',
#   'roomTypeId': 19808,
#   'grossAreaName': {'m2': '110D', 'p': '33D'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:36:38',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19808/4926f4f68a324d228f7330405eeac4a6.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '110D', 'p': '33D'},
#   'isNew': True,
#   'sales': 175000},
#  {'itemId': 26972947,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능한매매,확장형,에2,탁트인전망으로채광과개방감굿',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:27:52.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '108동',
#   'roomTypeId': 19810,
#   'grossAreaName': {'m2': 160, 'p': 48},
#   'grossArea': {'m2': 160, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 129, 'p': 39},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:34:55',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 160, 'p': 48},
#   'isNew': True,
#   'sales': 198000},
#  {'itemId': 26972868,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주협의,에어컨1,확장형,채광과개방감굿,주인거주',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:26:05.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '106동',
#   'roomTypeId': 19806,
#   'grossAreaName': {'m2': '107A', 'p': '32A'},
#   'grossArea': {'m2': 107, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19806/11cfe22e619746c0ab03126742439857.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:32:36',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19806/11cfe22e619746c0ab03126742439857.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '107A', 'p': '32A'},
#   'isNew': True,
#   'sales': 167000},
#  {'itemId': 26972826,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능한매매,풀에어컨,확장형,채광과시원한개방감굿',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:24:37.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '103동',
#   'roomTypeId': 19810,
#   'grossAreaName': {'m2': 160, 'p': 48},
#   'grossArea': {'m2': 160, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 129, 'p': 39},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:31:30',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 160, 'p': 48},
#   'isNew': True,
#   'sales': 210000},
#  {'itemId': 26972802,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5688608776878,
#   'lng': 127.02794524824768,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능한매매,확장형,채광굿, 막힘없는 시원한뷰',
#   'agentNo': 47136,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:21:08.000Z',
#   'apartmentId': 24894,
#   'apartmentName': '텐즈힐1단지',
#   'buildingName': '103동',
#   'roomTypeId': 19810,
#   'grossAreaName': {'m2': 160, 'p': 48},
#   'grossArea': {'m2': 160, 'p': 48},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 129, 'p': 39},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png',
#   'userNo': 5520475,
#   'agentId': 5520475,
#   'agentName': '투미공인중개사사무소',
#   'agentTel': '0222957777',
#   'agentUserName': '김제경',
#   'agentPhone': '01072564474',
#   'created_at': '2021-04-22 10:30:38',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/24894/19810/765def996a7b4a56bf894f2a05a111cb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 160, 'p': 48},
#   'isNew': True,
#   'sales': 195000},
#  {'itemId': 26972138,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55437159182884,
#   'lng': 127.03283790932718,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '기본형, 전세안고',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:18:42.000Z',
#   'apartmentId': 729,
#   'apartmentName': '신동아',
#   'buildingName': '8동',
#   'roomTypeId': 1961,
#   'grossAreaName': {'m2': 81, 'p': 24},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/729/1961/0eae9b6f4f4649d08ecd677a43a8f79a.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 10:02:33',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/729/1961/0eae9b6f4f4649d08ecd677a43a8f79a.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 81, 'p': 24},
#   'isNew': True,
#   'sales': 90000},
#  {'itemId': 26972093,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '19',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.553430107559,
#   'lng': 127.0357391828018,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '거실,방확장, 최신올수리,정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:18:38.000Z',
#   'apartmentId': 5645,
#   'apartmentName': '대림강변타운',
#   'buildingName': '103동',
#   'roomTypeId': 8955,
#   'grossAreaName': {'m2': '79A', 'p': '23A'},
#   'grossArea': {'m2': 79, 'p': 23},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5645/8955/fcf8200f29bb456abeb9582bf6844ca3.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 10:00:00',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5645/8955/fcf8200f29bb456abeb9582bf6844ca3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '79A', 'p': '23A'},
#   'isNew': True,
#   'sales': 130000},
#  {'itemId': 26972018,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '23',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55559257829403,
#   'lng': 127.0354867067092,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '확장안한 특올수리,  전세안고',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:18:25.000Z',
#   'apartmentId': 6021,
#   'apartmentName': '서울숲한신더휴',
#   'buildingName': '112동',
#   'roomTypeId': 9545,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 09:55:15',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 150000},
#  {'itemId': 26971963,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '25',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55306563712833,
#   'lng': 127.03725095663398,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장, 1층, 정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:16:55.000Z',
#   'apartmentId': 5993,
#   'apartmentName': '응봉리버그린동아',
#   'buildingName': '304동',
#   'roomTypeId': 9436,
#   'grossAreaName': {'m2': 108, 'p': 32},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/5993/9436/33490e7e8db34888b2afb915718329da.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 09:52:18',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/5993/9436/33490e7e8db34888b2afb915718329da.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 108, 'p': 32},
#   'isNew': True,
#   'sales': 132000},
#  {'itemId': 26971945,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '24',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55559257829403,
#   'lng': 127.0354867067092,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '기본형, 싱크대,욕실수리, 정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:16:54.000Z',
#   'apartmentId': 6021,
#   'apartmentName': '서울숲한신더휴',
#   'buildingName': '116동',
#   'roomTypeId': 9545,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 09:51:08',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 160000},
#  {'itemId': 26971937,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '24',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55559257829403,
#   'lng': 127.0354867067092,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '거실,방2확장, 올수리, 정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:16:52.000Z',
#   'apartmentId': 6021,
#   'apartmentName': '서울숲한신더휴',
#   'buildingName': '116동',
#   'roomTypeId': 9545,
#   'grossAreaName': {'m2': 142, 'p': 42},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 09:50:46',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/6021/9545/f53fac675d7a441ca83e9afe178536eb.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 142, 'p': 42},
#   'isNew': True,
#   'sales': 155000},
#  {'itemId': 26971922,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5519369,
#   'lng': 127.03326,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '남향,샷시교체,올수리, 정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:16:17.000Z',
#   'apartmentId': 211,
#   'apartmentName': '대림1차',
#   'buildingName': '2동',
#   'roomTypeId': 522,
#   'grossAreaName': {'m2': 147, 'p': 44},
#   'grossArea': {'m2': 147, 'p': 44},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 126, 'p': 38},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/211/522/a4504851fa4d4e798af6089d9cdab256.png',
#   'userNo': 7815056,
#   'agentId': 7815056,
#   'agentName': '행당공인중개사사무소',
#   'agentTel': '0222819171',
#   'agentUserName': '황순영',
#   'agentPhone': '01042679171',
#   'created_at': '2021-04-22 09:49:49',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/211/522/a4504851fa4d4e798af6089d9cdab256.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': 147, 'p': 44},
#   'isNew': True,
#   'sales': 200000},
#  {'itemId': 26971890,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '24',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55559257829403,
#   'lng': 127.0354867067092,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '급매,거실,방확장,정상입주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T06:16:12.000Z',
#   'apartmentId': 6021,
#   'apartmentName': '서울숲한신더휴',
#   'buildingName': '106동',
#   'roomTypeId': 9544,
#   'grossAreaName': {'m2': 108, 'p': 32},
#   'grossArea': {'m2': 108, 'p': 32},
#   'agreementArea': {'m2': 0, 'p': 0},
# ...
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5466768,
#   'lng': 127.026643,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '응봉산뷰가 멋진 관리 잘된집. 전세안고매매',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T01:27:17.000Z',
#   'apartmentId': 37269,
#   'apartmentName': '힐스테이트서울숲리버',
#   'buildingName': '113동',
#   'roomTypeId': 153559,
#   'grossAreaName': {'m2': '110A', 'p': '33A'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37269/153559/c070be7fc8b440afa199c4289d47a91e.png',
#   'userNo': 5604428,
#   'agentId': 5604428,
#   'agentName': '금나라부동산공인중개사사무소',
#   'agentTel': '0222813838',
#   'agentUserName': '구선회',
#   'agentPhone': '01076842999',
#   'created_at': '2021-04-21 16:36:10',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37269/153559/c070be7fc8b440afa199c4289d47a91e.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110A', 'p': '33A'},
#   'isNew': True,
#   'sales': 185000},
#  {'itemId': 26967105,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '12',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5466768,
#   'lng': 127.026643,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '응봉산뷰와 한강뷰가 멋진 집 층간소음무, 풀옵션 세안고매매',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T01:26:45.000Z',
#   'apartmentId': 37269,
#   'apartmentName': '힐스테이트서울숲리버',
#   'buildingName': '111동',
#   'roomTypeId': 153563,
#   'grossAreaName': {'m2': '142A', 'p': '42A'},
#   'grossArea': {'m2': 142, 'p': 42},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37269/153563/3f01490f2fe84dfebfb1519928ac2ca3.png',
#   'userNo': 5604428,
#   'agentId': 5604428,
#   'agentName': '금나라부동산공인중개사사무소',
#   'agentTel': '0222813838',
#   'agentUserName': '구선회',
#   'agentPhone': '01076842999',
#   'created_at': '2021-04-21 16:33:29',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37269/153563/3f01490f2fe84dfebfb1519928ac2ca3.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '142A', 'p': '42A'},
#   'isNew': True,
#   'sales': 225000},
#  {'itemId': 26967045,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '15',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.5466768,
#   'lng': 127.026643,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능 사이한강조망 좋아요~ 로얄동 로얄층',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T01:26:31.000Z',
#   'apartmentId': 37269,
#   'apartmentName': '힐스테이트서울숲리버',
#   'buildingName': '102동',
#   'roomTypeId': 153557,
#   'grossAreaName': {'m2': '81A', 'p': '24A'},
#   'grossArea': {'m2': 81, 'p': 24},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/37269/153557/1a72378405174efc8c5b6eda2ba1422e.png',
#   'userNo': 5604428,
#   'agentId': 5604428,
#   'agentName': '금나라부동산공인중개사사무소',
#   'agentTel': '0222813838',
#   'agentUserName': '구선회',
#   'agentPhone': '01076842999',
#   'created_at': '2021-04-21 16:30:49',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/37269/153557/1a72378405174efc8c5b6eda2ba1422e.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '81A', 'p': '24A'},
#   'isNew': True,
#   'sales': 148000},
#  {'itemId': 24451555,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능, 주인거주로 상태최상, 올확장, 풀시스템에어컨,',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '101동',
#   'roomTypeId': 17175,
#   'grossAreaName': {'m2': '85B', 'p': '25B'},
#   'grossArea': {'m2': 85, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17175/eed481b72be44d42ace2e7fdcc51e9b2.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2020-10-22 13:49:21',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17175/eed481b72be44d42ace2e7fdcc51e9b2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '85B', 'p': '25B'},
#   'isNew': True,
#   'sales': 125000},
#  {'itemId': 25109133,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '확트인 개방감 있는 집, 전세안고매매 갭투자 추천, 올확장',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '108동',
#   'roomTypeId': 17171,
#   'grossAreaName': {'m2': '110D', 'p': '33D'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17171/0129f6e7edb74cf7b2883641bbbb3654.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2020-12-09 14:44:12',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17171/0129f6e7edb74cf7b2883641bbbb3654.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110D', 'p': '33D'},
#   'isNew': True,
#   'sales': 155000},
#  {'itemId': 25109250,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '완전 트인뷰, 시원한개방감,채광좋은 집,저렴한 매매,상태굿',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '105동',
#   'roomTypeId': 17169,
#   'grossAreaName': {'m2': '110A', 'p': '33A'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2020-12-09 14:50:03',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110A', 'p': '33A'},
#   'isNew': True,
#   'sales': 150000},
#  {'itemId': 25840748,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '완전 트인 뷰, 올확장, 주인거주, 상태 최상, 입주 여유',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '105동',
#   'roomTypeId': 17169,
#   'grossAreaName': {'m2': '110A', 'p': '33A'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-01-29 18:34:27',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '110A', 'p': '33A'},
#   'isNew': True,
#   'sales': 158000},
#  {'itemId': 26089159,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장, 채광좋은 완전 트인 전망, 입주가능, 상태최상',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '109동',
#   'roomTypeId': 17174,
#   'grossAreaName': {'m2': '85A', 'p': '25A'},
#   'grossArea': {'m2': 85, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17174/c1288e1886594251a9c3341bc2c6cc4d.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-02-18 09:57:31',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17174/c1288e1886594251a9c3341bc2c6cc4d.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '85A', 'p': '25A'},
#   'isNew': True,
#   'sales': 130000},
#  {'itemId': 26167840,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '정상입주, 올확장, 풀시스템에어컨6대, 주인거주로 상태깨끗',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '105동',
#   'roomTypeId': 17172,
#   'grossAreaName': {'m2': 149, 'p': 45},
#   'grossArea': {'m2': 149, 'p': 45},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 114, 'p': 34},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17172/64b42753185d4f38a66dd4278c77257d.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-02-23 14:58:42',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17172/64b42753185d4f38a66dd4278c77257d.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': 149, 'p': 45},
#   'isNew': True,
#   'sales': 170000},
#  {'itemId': 26425708,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '33입주가능 매물, 이쁜 정원뷰, 올확장, 주인거주',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '106동',
#   'roomTypeId': 17169,
#   'grossAreaName': {'m2': '110A', 'p': '33A'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-03-12 14:47:14',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '110A', 'p': '33A'},
#   'isNew': True,
#   'sales': 160000},
#  {'itemId': 26460510,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '입주가능, 확장. 단지 정원뷰, 상태 깨끗한 집 ',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '103동',
#   'roomTypeId': 17171,
#   'grossAreaName': {'m2': '110D', 'p': '33D'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17171/0129f6e7edb74cf7b2883641bbbb3654.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-03-15 15:54:23',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17171/0129f6e7edb74cf7b2883641bbbb3654.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '저층',
#   'agreementAreaName': {'m2': '110D', 'p': '33D'},
#   'isNew': True,
#   'sales': 155000},
#  {'itemId': 26539226,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '임대안고, 올확장, 채광좋은 남동향, 상태굿',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '101동',
#   'roomTypeId': 17175,
#   'grossAreaName': {'m2': '85B', 'p': '25B'},
#   'grossArea': {'m2': 85, 'p': 25},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 59, 'p': 17},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17175/eed481b72be44d42ace2e7fdcc51e9b2.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-03-20 16:20:48',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17175/eed481b72be44d42ace2e7fdcc51e9b2.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '고층',
#   'agreementAreaName': {'m2': '85B', 'p': '25B'},
#   'isNew': True,
#   'sales': 135000},
#  {'itemId': 26645444,
#   'type': '매매',
#   'exclusive_type': '1',
#   'rent': 0,
#   'buildingFloor': '20',
#   'itemImages': None,
#   'house_key': None,
#   'lat': 37.55129219494881,
#   'lng': 127.0245391485163,
#   'vr_status': None,
#   'vr_request_id': None,
#   'itemTitle': '올확장, 입주가능, 주인거주, 채광좋은 집 , 상태 최상',
#   'agentNo': None,
#   'regDate': '2021-04-22',
#   'regTime': '2021-04-22T00:55:55.000Z',
#   'apartmentId': 19722,
#   'apartmentName': '래미안하이리버',
#   'buildingName': '104동',
#   'roomTypeId': 17169,
#   'grossAreaName': {'m2': '110A', 'p': '33A'},
#   'grossArea': {'m2': 110, 'p': 33},
#   'agreementArea': {'m2': 0, 'p': 0},
#   'netArea': {'m2': 84, 'p': 25},
#   'floorPlan': 'https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png',
#   'userNo': 5701833,
#   'agentId': 5701833,
#   'agentName': '단지내OK공인중개사사무소',
#   'agentTel': '0222322727',
#   'agentUserName': '최영실',
#   'agentPhone': '01086656548',
#   'created_at': '2021-03-29 13:19:26',
#   'real_type': '아파트',
#   'itemImage': ['https://ic.zigbang.com/ic/floorplan/19722/17169/ccc129f6419c4ad8a48ba262a79b6e23.png'],
#   'sectionType': 'premium_recommend',
#   'viewType': 1,
#   'groupedItemFloor': '중층',
#   'agreementAreaName': {'m2': '110A', 'p': '33A'},
#   'isNew': True,
#   'sales': 150000}]

# %%
import pandas as pd
item_df = pd.DataFrame(datas)
item_df
# Out:
#       agentId       agentName  agentNo   agentPhone    agentTel agentUserName  \
# 0     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 1     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 2     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 3     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 4     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 5     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 6     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 7     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 8     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 9     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 10    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 11    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 12    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 13    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 14    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 15    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 16    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 17    3553010         거성공인중개사      NaN  01085071969  0222984989           김정의
# 18    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 19    7815056      행당공인중개사사무소      NaN  01042679171  0222819171           황순영
# 20    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 21      76860      열린공인중개사사무소      NaN  01054330295  0222954949           강도인
# 22    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 23    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 24   10804703      열린공인중개사사무소      NaN  01022259644  0222567700           김명옥
# 25    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 26    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 27    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 28    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 29    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# ..        ...             ...      ...          ...         ...           ...
# 170   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 171   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 172   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 173   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 174   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 175   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 176   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 177   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 178   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 179   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 180   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 181   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 182   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 183   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 184   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 185   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 186   5604428  금나라부동산공인중개사사무소      NaN  01076842999  0222813838           구선회
# 187   5604428  금나라부동산공인중개사사무소      NaN  01076842999  0222813838           구선회
# 188   5604428  금나라부동산공인중개사사무소      NaN  01076842999  0222813838           구선회
# 189   5604428  금나라부동산공인중개사사무소      NaN  01076842999  0222813838           구선회
# 190   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 191   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 192   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 193   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 194   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 195   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 196   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 197   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 198   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
# 199   5701833   단지내OK공인중개사사무소      NaN  01086656548  0222322727           최영실
#
#          agreementArea           agreementAreaName  apartmentId apartmentName  \
# 0    {'m2': 0, 'p': 0}        {'m2': 160, 'p': 48}        24894        텐즈힐1단지
# 1    {'m2': 0, 'p': 0}        {'m2': 160, 'p': 48}        24894        텐즈힐1단지
# 2    {'m2': 0, 'p': 0}  {'m2': '109E', 'p': '32E'}        33613          센트라스
# 3    {'m2': 0, 'p': 0}  {'m2': '110B', 'p': '33B'}        24894        텐즈힐1단지
# 4    {'m2': 0, 'p': 0}  {'m2': '109E', 'p': '32E'}        33613          센트라스
# 5    {'m2': 0, 'p': 0}  {'m2': '111A', 'p': '33A'}        33613          센트라스
# 6    {'m2': 0, 'p': 0}  {'m2': '110D', 'p': '33D'}        24894        텐즈힐1단지
# 7    {'m2': 0, 'p': 0}        {'m2': 179, 'p': 54}        24894        텐즈힐1단지
# 8    {'m2': 0, 'p': 0}  {'m2': '111A', 'p': '33A'}        33613          센트라스
# 9    {'m2': 0, 'p': 0}   {'m2': '83C', 'p': '25C'}        33613          센트라스
# 10   {'m2': 0, 'p': 0}   {'m2': '86A', 'p': '26A'}        22637        텐즈힐2단지
# 11   {'m2': 0, 'p': 0}         {'m2': 57, 'p': 17}        33613          센트라스
# 12   {'m2': 0, 'p': 0}  {'m2': '109C', 'p': '32C'}        22637        텐즈힐2단지
# 13   {'m2': 0, 'p': 0}  {'m2': '107A', 'p': '32A'}        22637        텐즈힐2단지
# 14   {'m2': 0, 'p': 0}        {'m2': 149, 'p': 45}        33613          센트라스
# 15   {'m2': 0, 'p': 0}  {'m2': '109C', 'p': '32C'}        22637        텐즈힐2단지
# 16   {'m2': 0, 'p': 0}  {'m2': '111A', 'p': '33A'}        33613          센트라스
# 17   {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 18   {'m2': 0, 'p': 0}  {'m2': '111A', 'p': '33A'}        33613          센트라스
# 19   {'m2': 0, 'p': 0}   {'m2': '79A', 'p': '23A'}         5645        대림강변타운
# 20   {'m2': 0, 'p': 0}        {'m2': 149, 'p': 45}        33613          센트라스
# 21   {'m2': 0, 'p': 0}         {'m2': 73, 'p': 22}        12313     서울숲푸르지오1차
# 22   {'m2': 0, 'p': 0}   {'m2': '82C', 'p': '24C'}        36892         왕십리자이
# 23   {'m2': 0, 'p': 0}        {'m2': 112, 'p': 33}        36892         왕십리자이
# 24   {'m2': 0, 'p': 0}   {'m2': '88G', 'p': '26G'}        33613          센트라스
# 25   {'m2': 0, 'p': 0}  {'m2': '110D', 'p': '33D'}        24894        텐즈힐1단지
# 26   {'m2': 0, 'p': 0}   {'m2': '83A', 'p': '25A'}        24894        텐즈힐1단지
# 27   {'m2': 0, 'p': 0}  {'m2': '110D', 'p': '33D'}        24894        텐즈힐1단지
# 28   {'m2': 0, 'p': 0}        {'m2': 160, 'p': 48}        24894        텐즈힐1단지
# 29   {'m2': 0, 'p': 0}  {'m2': '107A', 'p': '32A'}        24894        텐즈힐1단지
# ..                 ...                         ...          ...           ...
# 170  {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 171  {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 172  {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 173  {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 174  {'m2': 0, 'p': 0}        {'m2': 104, 'p': 31}         5361          행당대림
# 175  {'m2': 0, 'p': 0}         {'m2': 83, 'p': 25}         5361          행당대림
# 176  {'m2': 0, 'p': 0}         {'m2': 83, 'p': 25}         5361          행당대림
# 177  {'m2': 0, 'p': 0}        {'m2': 137, 'p': 41}         5361          행당대림
# 178  {'m2': 0, 'p': 0}         {'m2': 74, 'p': 22}         6323      왕십리풍림아이원
# 179  {'m2': 0, 'p': 0}        {'m2': 144, 'p': 43}         6323      왕십리풍림아이원
# 180  {'m2': 0, 'p': 0}        {'m2': 144, 'p': 43}         6323      왕십리풍림아이원
# 181  {'m2': 0, 'p': 0}         {'m2': 74, 'p': 22}         6323      왕십리풍림아이원
#
# 6     매매   4906352        1          None       None
# 7     매매   4906352        1          None       None
# 8     매매   4906352        1          None       None
# 9     매매   4906352        1          None       None
# 10    매매   4906352        1          None       None
# 11    매매   4906352        1          None       None
# 12    매매   4906352        1          None       None
# 13    매매   4906352        1          None       None
# 14    매매   4906352        1          None       None
# 15    매매   4906352        1          None       None
# 16    매매   4906352        1          None       None
# 17    매매   3553010        1          None       None
# 18    매매   4906352        1          None       None
# 19    매매   7815056        1          None       None
# 20    매매   4906352        1          None       None
# 21    매매     76860        1          None       None
# 22    매매   5520475        1          None       None
# 23    매매   5520475        1          None       None
# 24    매매  10804703        1          None       None
# 25    매매   5520475        1          None       None
# 26    매매   5520475        1          None       None
# 27    매매   5520475        1          None       None
# 28    매매   5520475        1          None       None
# 29    매매   5520475        1          None       None
# ..   ...       ...      ...           ...        ...
# 170   매매   2769577        1          None       None
# 171   매매   2769577        1          None       None
# 172   매매   2769577        1          None       None
# 173   매매   2769577        1          None       None
# 174   매매   2769577        1          None       None
# 175   매매   2769577        1          None       None
# 176   매매   2769577        1          None       None
# 177   매매   2769577        1          None       None
# 178   매매   2769577        1          None       None
# 179   매매   2769577        1          None       None
# 180   매매   2769577        1          None       None
# 181   매매   2769577        1          None       None
# 182   매매   2769577        1          None       None
# 183   매매   2769577        1          None       None
# 184   매매   2769577        1          None       None
# 185   매매   2769577        1          None       None
# 186   매매   5604428        1          None       None
# 187   매매   5604428        1          None       None
# 188   매매   5604428        1          None       None
# 189   매매   5604428        1          None       None
# 190   매매   5701833        1          None       None
# 191   매매   5701833        1          None       None
# 192   매매   5701833        1          None       None
# 193   매매   5701833        1          None       None
# 194   매매   5701833        1          None       None
# 195   매매   5701833        1          None       None
# 196   매매   5701833        1          None       None
# 197   매매   5701833        1          None       None
# 198   매매   5701833        1          None       None
# 199   매매   5701833        1          None       None
#
# [200 rows x 39 columns]

# %%
len(item_df.columns)
# Out:
# 39

# %%
# pandas option 설정
pd.options.display.max_columns = len(item_df.columns)

# %%
item_df
# Out:
#       agentId       agentName  agentNo   agentPhone    agentTel agentUserName  \
# 0     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 1     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 2     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 3     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 4     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 5     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 6     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 7     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 8     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 9     4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 10    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 11    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 12    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 13    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 14    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 15    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 16    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 17    3553010         거성공인중개사      NaN  01085071969  0222984989           김정의
# 18    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 19    7815056      행당공인중개사사무소      NaN  01042679171  0222819171           황순영
# 20    4906352  센트라스리치공인중개사사무소      NaN  01052395337  0222342201           손수연
# 21      76860      열린공인중개사사무소      NaN  01054330295  0222954949           강도인
# 22    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 23    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 24   10804703      열린공인중개사사무소      NaN  01022259644  0222567700           김명옥
# 25    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 26    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 27    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 28    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# 29    5520475      투미공인중개사사무소  47136.0  01072564474  0222957777           김제경
# ..        ...             ...      ...          ...         ...           ...
# 170   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 171   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 172   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 173   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 174   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 175   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 176   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 177   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 178   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 179   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 180   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 181   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 182   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 183   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
# 184   2769577         신용공인중개사      NaN  01084300204  0222993114           남혜영
#
# 12   https://ic.zigbang.com/ic/floorplan/22637/1922...  {'m2': 109, 'p': 32}
# 13   https://ic.zigbang.com/ic/floorplan/22637/1922...  {'m2': 107, 'p': 32}
# 14   https://ic.zigbang.com/ic/floorplan/33613/1497...  {'m2': 149, 'p': 45}
# 15   https://ic.zigbang.com/ic/floorplan/22637/1922...  {'m2': 109, 'p': 32}
# 16   https://ic.zigbang.com/ic/floorplan/33613/1497...  {'m2': 111, 'p': 33}
# 17   https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 18   https://ic.zigbang.com/ic/floorplan/33613/1497...  {'m2': 111, 'p': 33}
# 19   https://ic.zigbang.com/ic/floorplan/5645/8955/...   {'m2': 79, 'p': 23}
# 20   https://ic.zigbang.com/ic/floorplan/33613/1497...  {'m2': 149, 'p': 45}
# 21   https://ic.zigbang.com/ic/floorplan/12313/1300...   {'m2': 73, 'p': 22}
# 22   https://ic.zigbang.com/ic/floorplan/36892/1516...   {'m2': 82, 'p': 24}
# 23   https://ic.zigbang.com/ic/floorplan/36892/1516...  {'m2': 112, 'p': 33}
# 24   https://ic.zigbang.com/ic/floorplan/33613/1496...   {'m2': 88, 'p': 26}
# 25   https://ic.zigbang.com/ic/floorplan/24894/1980...  {'m2': 110, 'p': 33}
# 26   https://ic.zigbang.com/ic/floorplan/24894/1981...   {'m2': 83, 'p': 25}
# 27   https://ic.zigbang.com/ic/floorplan/24894/1980...  {'m2': 110, 'p': 33}
# 28   https://ic.zigbang.com/ic/floorplan/24894/1981...  {'m2': 160, 'p': 48}
# 29   https://ic.zigbang.com/ic/floorplan/24894/1980...  {'m2': 107, 'p': 32}
# ..                                                 ...                   ...
# 170  https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 171  https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 172  https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 173  https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 174  https://ic.zigbang.com/ic/floorplan/5361/8644/...  {'m2': 104, 'p': 31}
# 175  https://ic.zigbang.com/ic/floorplan/5361/8646/...   {'m2': 83, 'p': 25}
# 176  https://ic.zigbang.com/ic/floorplan/5361/8646/...   {'m2': 83, 'p': 25}
# 177  https://ic.zigbang.com/ic/floorplan/5361/8645/...  {'m2': 137, 'p': 41}
# 178  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 179  https://ic.zigbang.com/ic/floorplan/6323/10316...  {'m2': 144, 'p': 43}
# 180  https://ic.zigbang.com/ic/floorplan/6323/10316...  {'m2': 144, 'p': 43}
# 181  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 182  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 183  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 184  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 185  https://ic.zigbang.com/ic/floorplan/6323/10317...   {'m2': 74, 'p': 22}
# 186  https://ic.zigbang.com/ic/floorplan/37269/1535...   {'m2': 88, 'p': 26}
# 187  https://ic.zigbang.com/ic/floorplan/37269/1535...  {'m2': 110, 'p': 33}
# 188  https://ic.zigbang.com/ic/floorplan/37269/1535...  {'m2': 142, 'p': 42}
# 189  https://ic.zigbang.com/ic/floorplan/37269/1535...   {'m2': 81, 'p': 24}
# 190  https://ic.zigbang.com/ic/floorplan/19722/1717...   {'m2': 85, 'p': 25}
# 191  https://ic.zigbang.com/ic/floorplan/19722/1717...  {'m2': 110, 'p': 33}
# 192  https://ic.zigbang.com/ic/floorplan/19722/1716...  {'m2': 110, 'p': 33}
# 193  https://ic.zigbang.com/ic/floorplan/19722/1716...  {'m2': 110, 'p': 33}
# 194  https://ic.zigbang.com/ic/floorplan/19722/1717...   {'m2': 85, 'p': 25}
# 195  https://ic.zigbang.com/ic/floorplan/19722/1717...  {'m2': 149, 'p': 45}
# 196  https://ic.zigbang.com/ic/floorplan/19722/1716...  {'m2': 110, 'p': 33}
# 197  https://ic.zigbang.com/ic/floorplan/19722/1717...  {'m2': 110, 'p': 33}
# 198  https://ic.zigbang.com/ic/floorplan/19722/1717...   {'m2': 85, 'p': 25}
# 199  https://ic.zigbang.com/ic/floorplan/19722/1716...  {'m2': 110, 'p': 33}
#
#                   grossAreaName groupedItemFloor house_key  isNew    itemId  \
# 0          {'m2': 160, 'p': 48}               중층      None   True  26979147
# 1          {'m2': 160, 'p': 48}               고층      None   True  26978981
# 2    {'m2': '109E', 'p': '32E'}               중층      None   True  26978950
# 3    {'m2': '110B', 'p': '33B'}               고층      None   True  26978404
# 4    {'m2': '109E', 'p': '32E'}               중층      None   True  26978351
# 5    {'m2': '111A', 'p': '33A'}               고층      None   True  26978323
# 6    {'m2': '110D', 'p': '33D'}               저층      None   True  26978296
# 7          {'m2': 179, 'p': 54}               저층      None   True  26978248
# 8    {'m2': '111A', 'p': '33A'}               저층      None   True  26978213
# 9     {'m2': '83C', 'p': '25C'}               고층      None   True  26978200
# 10    {'m2': '86A', 'p': '26A'}               고층      None   True  26978175
# 11          {'m2': 57, 'p': 17}               고층      None   True  26978157
# 12   {'m2': '109C', 'p': '32C'}               고층      None   True  26978140
# 13   {'m2': '107A', 'p': '32A'}               중층      None   True  26978129
# 14         {'m2': 149, 'p': 45}               고층      None   True  26978118
# 15   {'m2': '109C', 'p': '32C'}               고층      None   True  26978095
# 16   {'m2': '111A', 'p': '33A'}               고층      None   True  26978061
# 17         {'m2': 104, 'p': 31}               고층      None   True  26978015
# 18   {'m2': '111A', 'p': '33A'}               고층      None   True  26978010
# 19    {'m2': '79A', 'p': '23A'}               고층      None   True  26978005
# 20         {'m2': 149, 'p': 45}               고층      None   True  26977979
# 21          {'m2': 73, 'p': 22}               중층      None   True  26975026
# 22    {'m2': '82C', 'p': '24C'}               고층      None   True  26973914
# 23         {'m2': 112, 'p': 33}               고층      None   True  26973896
# 24    {'m2': '88G', 'p': '26G'}               고층      None   True  26973668
# 25   {'m2': '110D', 'p': '33D'}               고층      None   True  26973457
# 26    {'m2': '83A', 'p': '25A'}               저층      None   True  26973108
# 27   {'m2': '110D', 'p': '33D'}               저층      None   True  26972997
# 28         {'m2': 160, 'p': 48}               고층      None   True  26972947
# 29   {'m2': '107A', 'p': '32A'}               고층      None   True  26972868
# ..                          ...              ...       ...    ...       ...
# 170        {'m2': 104, 'p': 31}               고층      None   True  26640196
# 171        {'m2': 104, 'p': 31}               중층      None   True  26817013
# 172        {'m2': 104, 'p': 31}               고층      None   True  26817041
# 173        {'m2': 104, 'p': 31}               고층      None   True  26817065
# 174        {'m2': 104, 'p': 31}               고층      None   True  26817107
# 175         {'m2': 83, 'p': 25}               중층      None   True  26817154
# 176         {'m2': 83, 'p': 25}               고층      None   True  26845734
# 177        {'m2': 137, 'p': 41}               저층      None   True  26846154
# 178         {'m2': 74, 'p': 22}               저층      None   True  26738517
# 179        {'m2': 144, 'p': 43}               고층      None   True  26742275
# 180        {'m2': 144, 'p': 43}               고층      None   True  26759034
# 181         {'m2': 74, 'p': 22}               고층      None   True  26883275
# 182         {'m2': 74, 'p': 22}               고층      None   True  26883318
# 183         {'m2': 74, 'p': 22}               고층      None   True  26883647
# 184         {'m2': 74, 'p': 22}               저층      None   True  26883900
# 185         {'m2': 74, 'p': 22}               고층      None   True  26939663
# 186         {'m2': 88, 'p': 26}               고층      None   True  26967280
# 187  {'m2': '110A', 'p': '33A'}               고층      None   True  26967172
# 188  {'m2': '142A', 'p': '42A'}               고층      None   True  26967105
# 189   {'m2': '81A', 'p': '24A'}               중층      None   True  26967045
# 190   {'m2': '85B', 'p': '25B'}               저층      None   True  24451555
# 191  {'m2': '110D', 'p': '33D'}               고층      None   True  25109133
# 192  {'m2': '110A', 'p': '33A'}               고층      None   True  25109250
# 193  {'m2': '110A', 'p': '33A'}               고층      None   True  25840748
# 194   {'m2': '85A', 'p': '25A'}               고층      None   True  26089159
# 195        {'m2': 149, 'p': 45}               저층      None   True  26167840
# 196  {'m2': '110A', 'p': '33A'}               중층      None   True  26425708
# 197  {'m2': '110D', 'p': '33D'}               저층      None   True  26460510
# 198   {'m2': '85B', 'p': '25B'}               고층      None   True  26539226
# 199  {'m2': '110A', 'p': '33A'}               중층      None   True  26645444
#
#                                              itemImage itemImages  \
# 0    [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 1    [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 2    [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 3    [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 4    [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 5    [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 6    [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 7    [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 8    [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 9    [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 10   [https://ic.zigbang.com/ic/floorplan/22637/192...       None
# 11   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 12   [https://ic.zigbang.com/ic/floorplan/22637/192...       None
# 13   [https://ic.zigbang.com/ic/floorplan/22637/192...       None
# 14   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 15   [https://ic.zigbang.com/ic/floorplan/22637/192...       None
# 16   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 17   [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 18   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 19   [https://ic.zigbang.com/ic/floorplan/5645/8955...       None
# 20   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 21   [https://ic.zigbang.com/ic/floorplan/12313/130...       None
# 22   [https://ic.zigbang.com/ic/floorplan/36892/151...       None
# 23   [https://ic.zigbang.com/ic/floorplan/36892/151...       None
# 24   [https://ic.zigbang.com/ic/floorplan/33613/149...       None
# 25   [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 26   [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 27   [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 28   [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# 29   [https://ic.zigbang.com/ic/floorplan/24894/198...       None
# ..                                                 ...        ...
# 170  [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 171  [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 172  [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 173  [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 174  [https://ic.zigbang.com/ic/floorplan/5361/8644...       None
# 175  [https://ic.zigbang.com/ic/floorplan/5361/8646...       None
# 176  [https://ic.zigbang.com/ic/floorplan/5361/8646...       None
# 177  [https://ic.zigbang.com/ic/floorplan/5361/8645...       None
# 178  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 179  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 180  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 181  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 182  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 183  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 184  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 185  [https://ic.zigbang.com/ic/floorplan/6323/1031...       None
# 186  [https://ic.zigbang.com/ic/floorplan/37269/153...       None
# 187  [https://ic.zigbang.com/ic/floorplan/37269/153...       None
# 188  [https://ic.zigbang.com/ic/floorplan/37269/153...       None
# 189  [https://ic.zigbang.com/ic/floorplan/37269/153...       None
# 190  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 191  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 192  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 193  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 194  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 195  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 196  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 197  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 198  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
# 199  [https://ic.zigbang.com/ic/floorplan/19722/171...       None
#
#                             itemTitle        lat         lng  \
# 0                    올확장형.입주가능한매물입니다.  37.568861  127.027945
# 1                  역세권.탁트인전망.임대안고입니다.  37.568861  127.027945
# 2                         역세권.판상형.에어컨  37.565539  127.027069
# 3                             판상형.에어컨  37.568861  127.027945
# 4                         에어컨.판상형입니다.  37.565539  127.027069
# 5                            초역세권.에어컨  37.565539  127.027069
# 6                         에어컨.로얄동.판상형  37.568861  127.027945
# 7                       올확장.에어컨6.입주가능  37.568861  127.027945
# 8                 역세권.에어컨.입주가능한매물입니다.  37.565539  127.027069
# 9                  에어컨3,확장.지하쳘연결동입니다.  37.565539  127.027069
# 10                남향,올확장,확트인전망의매물입니다.  37.570465  127.024673
# 11                 초역세권,에어컨,저렴한매물입니다.  37.565539  127.027069
# 12                 남향.로얄동.입주가능한매물입니다.  37.570465  127.024673
# 13                     올확징.입주가능.탁트인전망  37.570465  127.024673
# 14                에어컨3,역세권,빠른입주가능합니다.  37.565539  127.027069
# 15             에어컨3,확장,남향,입주가능한매물입니다.  37.570465  127.024673
# 185     0       10317  105000  premium_recommend   매매   2769577         1
# 186     0      153558  155000  premium_recommend   매매   5604428         1
# 187     0      153559  185000  premium_recommend   매매   5604428         1
# 188     0      153563  225000  premium_recommend   매매   5604428         1
# 189     0      153557  148000  premium_recommend   매매   5604428         1
# 190     0       17175  125000  premium_recommend   매매   5701833         1
# 191     0       17171  155000  premium_recommend   매매   5701833         1
# 192     0       17169  150000  premium_recommend   매매   5701833         1
# 193     0       17169  158000  premium_recommend   매매   5701833         1
# 194     0       17174  130000  premium_recommend   매매   5701833         1
# 195     0       17172  170000  premium_recommend   매매   5701833         1
# 196     0       17169  160000  premium_recommend   매매   5701833         1
# 197     0       17171  155000  premium_recommend   매매   5701833         1
# 198     0       17175  135000  premium_recommend   매매   5701833         1
# 199     0       17169  150000  premium_recommend   매매   5701833         1
#
#     vr_request_id vr_status
# 0            None      None
# 1            None      None
# 2            None      None
# 3            None      None
# 4            None      None
# 5            None      None
# 6            None      None
# 7            None      None
# 8            None      None
# 9            None      None
# 10           None      None
# 11           None      None
# 12           None      None
# 13           None      None
# 14           None      None
# 15           None      None
# 16           None      None
# 17           None      None
# 18           None      None
# 19           None      None
# 20           None      None
# 21           None      None
# 22           None      None
# 23           None      None
# 24           None      None
# 25           None      None
# 26           None      None
# 27           None      None
# 28           None      None
# 29           None      None
# ..            ...       ...
# 170          None      None
# 171          None      None
# 172          None      None
# 173          None      None
# 174          None      None
# 175          None      None
# 176          None      None
# 177          None      None
# 178          None      None
# 179          None      None
# 180          None      None
# 181          None      None
# 182          None      None
# 183          None      None
# 184          None      None
# 185          None      None
# 186          None      None
# 187          None      None
# 188          None      None
# 189          None      None
# 190          None      None
# 191          None      None
# 192          None      None
# 193          None      None
# 194          None      None
# 195          None      None
# 196          None      None
# 197          None      None
# 198          None      None
# 199          None      None
#
# [200 rows x 39 columns]

# %%
columns = ["itemId", "buildingFloor", "groupedItemFloor", "grossArea",
           "lat", "lng", "sales", "itemTitle"
          ]
item_df = item_df[columns]
item_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor             grossArea        lat  \
# 198  26539226            20               고층   {'m2': 85, 'p': 25}  37.551292
# 199  26645444            20               중층  {'m2': 110, 'p': 33}  37.551292
#
#             lng   sales                        itemTitle
# 198  127.024539  135000         임대안고, 올확장, 채광좋은 남동향, 상태굿
# 199  127.024539  150000  올확장, 입주가능, 주인거주, 채광좋은 집 , 상태 최상

# %%
item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
item_df.drop(columns=["grossArea"], inplace=True)
item_df.tail()
# Out:
# C:\Users\challenge\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\challenge\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\challenge\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 195  26167840            20               저층  37.551292  127.024539  170000
# 196  26425708            20               중층  37.551292  127.024539  160000
# 197  26460510            20               저층  37.551292  127.024539  155000
# 198  26539226            20               고층  37.551292  127.024539  135000
# 199  26645444            20               중층  37.551292  127.024539  150000
#
#                             itemTitle   m2   p
# 195  정상입주, 올확장, 풀시스템에어컨6대, 주인거주로 상태깨끗  149  45
# 196      33입주가능 매물, 이쁜 정원뷰, 올확장, 주인거주  110  33
# 197       입주가능, 확장. 단지 정원뷰, 상태 깨끗한 집   110  33
# 198          임대안고, 올확장, 채광좋은 남동향, 상태굿   85  25
# 199   올확장, 입주가능, 주인거주, 채광좋은 집 , 상태 최상  110  33

# %% [markdown]
# #### 함수로 만들기
# - 동이름 -> 아파트 매물 데이터 프레임

# %%
def crawling_apt(addr):
    # 동이름 -> 위도, 경도
    serviceType = "아파트"
    url = "https://apis.zigbang.com/v2/search?leaseYn=N&q={}&serviceType={}".format(addr, serviceType)
    
    response = requests.get(url)
    data = response.json()["items"][0]
    lat, lng = data["lat"], data["lng"]

    # 위도, 경도 -> geohash
    geohash = geohash2.encode(lat, lng, precision=5)
    
    # geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?domain=zigbang&geohash={}&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    # ids -> items : 200개씩
    dfs = []
    for idx in range(0, len(ids), 200):
        start, end = idx, idx + 200
        ids_str = str(ids[start:end]).replace(" ", "")
        url = "https://apis.zigbang.com/property/apartments/items?vritemIds={ids}&itemIds{ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = ["itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle"]
        item_df = item_df[columns]
        
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        
        dfs.append(item_df)
    
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    
    return result_df

# %%
result = crawling_apt("성수동")

# %%
result.tail()
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 610  26814656            15               중층  37.530627  127.026139  330000
# 611  26813779            15               중층  37.532918  127.028126  500000
# 612  26813399            14               중층  37.529945  127.028905  600000
# 613  26813312            14               고층  37.529945  127.028905  450000
# 614  26813056            25               고층  37.565539  127.027069  128000
#
#                          itemTitle   m2   p
# 610                       조합원 승계조건  105  31
# 611                      급매급급매 한강변  172  52
# 612              급매 가격이 좋은 새로올수리된집  212  64
# 613                   남향 씨티뷰 전망좋은집  156  47
# 614  빠른입주가능, 확장형, 해 잘드는 남향 ,더블역세권    88  26

# %%
# 도곡동에서 30층 이상 되는 아파트에 고층 매물 찾아서 구매?

# %%
items_df = crawling_apt("도곡동")
items_df.tail()
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 107  26763719            30               고층  37.493337  127.026873  260000
# 108  26763846            32               고층  37.493337  127.026873  310000
# 109  26422453            26               중층  37.501423  127.012909  245000
# 110  26422507            26               고층  37.501423  127.012909  252000
# 111  26422681            31               고층  37.501759  127.017936  230000
#
#                           itemTitle   m2   p
# 107                 임대10억에80승계,내부깔끔  111  33
# 108            1억에400임대승계,넓고 구조 좋아요  144  43
# 109       생활편리성 좋은 위치,반포학원가 바로 인접,    92  27
# 110       입주 가능, 시세 반영한 전세가로 임대 가능    92  27
# 111  입주가능한 매물,확트인 전망이 더없이 좋은 매물입니다.   78  23

# %%
items_df.dtypes
items_df = items_df[items_df["buildingFloor"].notnull()]
items_df.reset_index(drop=True, inplace=True)
items_df.tail(2)
# Out:
#        itemId buildingFloor groupedItemFloor        lat         lng   sales  \
# 110  26422507            26               고층  37.501423  127.012909  252000
# 111  26422681            31               고층  37.501759  127.017936  230000
#
#                           itemTitle  m2   p
# 110       입주 가능, 시세 반영한 전세가로 임대 가능   92  27
# 111  입주가능한 매물,확트인 전망이 더없이 좋은 매물입니다.  78  23

# %%
items_df["buildingFloor"] = items_df["buildingFloor"].astype("int")

# %%
result_df = items_df[
    (items_df["buildingFloor"] >= 30)
    & (items_df["groupedItemFloor"] == "고층")
]
len(result_df)
# Out:
# 14

# %%
result_df.dtypes
# Out:
# itemId                int64
# buildingFloor         int32
# groupedItemFloor     object
# lat                 float64
# lng                 float64
# sales                 int64
# itemTitle            object
# m2                    int64
# p                     int64
# dtype: object

# %%
import numpy as np

# %%
np.average(result_df["sales"]) # 단위 만원
# Out:
# 280357.14285714284

# %%
np.min(result_df["sales"]) # 단위 만원
# Out:
# 215000

# %%
# %%writefile zigbang.py
import pandas as pd
import requests
import geohash2

def crawling_apt(addr):
    # 동이름 -> 위도, 경도
    serviceType = "아파트"
    url = "https://apis.zigbang.com/v2/search?leaseYn=N&q={}&serviceType={}".format(addr, serviceType)
    
    response = requests.get(url)
    data = response.json()["items"][0]
    lat, lng = data["lat"], data["lng"]

    # 위도, 경도 -> geohash
    geohash = geohash2.encode(lat, lng, precision=5)
    
    # geohash -> ids
    url = "https://apis.zigbang.com/property/apartments/items?domain=zigbang&geohash={}&q=type=sales%7Cprice=0~-1%7CfloorArea=0~-1".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["itemId"] for data in datas]
    
    # ids -> items : 200개씩
    dfs = []
    for idx in range(0, len(ids), 200):
        start, end = idx, idx + 200
        ids_str = str(ids[start:end]).replace(" ", "")
        url = "https://apis.zigbang.com/property/apartments/items?vritemIds={ids}&itemIds{ids}&citemIds={ids}".format(ids=ids_str)
        response = requests.get(url)
        datas = response.json()["items"]
        item_df = pd.DataFrame(datas)
        columns = ["itemId", "buildingFloor", "groupedItemFloor", "grossArea", "lat", "lng", "sales", "itemTitle"]
        item_df = item_df[columns]
        
        item_df["m2"] = item_df["grossArea"].apply(lambda data: data["m2"])
        item_df["p"] = item_df["grossArea"].apply(lambda data: data["p"])
        item_df.drop(columns=["grossArea"], inplace=True)
        
        dfs.append(item_df)
    
    result_df = pd.concat(dfs)
    result_df.reset_index(drop=True, inplace=True)
    
    return result_df
# Out:
# Writing zigbang.py
