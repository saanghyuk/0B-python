# %%
from selenium import webdriver
from PIL import Image as pil

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
driver = webdriver.Chrome(options=options)

# %% [markdown]
# 이거 띄워놓고 서버에서 ` ps -e | grep browse` 해보면, 떠있는거 확인 가능

# %%
driver.get("https://naver.com")
driver.save_screenshot("naver_main.png")
driver.quit()

# %% [markdown]
# `ps -e | grep browse` 해보면 안잡힘

# %% [markdown]
# #### 저장한 이미지 확인

# %%
pil_im = pil.open("naver_main.png")
pil_im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x7F1EFFA626A0>

# %% [markdown]
# - headless판단해서 안되게 하는 애들이 있음. ex) youtube, coupang etc.
# - xvfb라고 해서 가상화면 띄우는 프로그램 써야 함.
